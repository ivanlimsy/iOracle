# %% [markdown]
# # GBQ Script

# %% [markdown]
# ## get df

# %%
import pandas as pd

# read file temp (from data script)
def read_local(path_filename):
    """
    read_local(path_filename)
    reads the csv file and parses date col as date, setting the date as the index
    returns the df
    """
    df = pd.read_csv(path_filename)
    df['Date'] = pd.to_datetime(df['Date'])
    return df.set_index('Date')
    
df = read_local("play.csv")
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-01-03   28.950001   29.082500   28.690001   29.037500   27.332472
# 2017-01-04   28.962500   29.127501   28.937500   29.004999   27.301876
# 2017-01-05   28.980000   29.215000   28.952499   29.152500   27.440716
# 2017-01-06   29.195000   29.540001   29.117500   29.477501   27.746637
# 2017-01-09   29.487499   29.857500   29.485001   29.747499   28.000778
# ...                ...         ...         ...         ...         ...
# 2020-12-24  131.320007  133.460007  131.100006  131.970001  131.161407
# 2020-12-28  133.990005  137.339996  133.509995  136.690002  135.852509
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  134.043640
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  132.900696
# 2020-12-31  134.080002  134.740005  131.720001  132.690002  131.876999
#
#                Volume
# Date
# 2017-01-03  115127600
# 2017-01-04   84472400
# 2017-01-05   88774400
# 2017-01-06  127007600
# 2017-01-09  134247600
# ...               ...
# 2020-12-24   54930100
# 2020-12-28  124486200
# 2020-12-29  121047300
# 2020-12-30   96452100
# 2020-12-31   99116600
#
# [1007 rows x 6 columns]

# %% [markdown]
# ## get splits

# %%
#splits from time split
from datetime import datetime as dt

class train_val_split:
    
    def __init__(self, df, duration=30, window=1, prediction_period=5, start = '2018-01-01', end = '2020-03-31'):
        self.duration = duration # training period, for dates
        self.window = window # rolling window freq, for dates
        self.prediction_period = prediction_period # prediciton horizon, for dates
        self.start = start
        self.end = end
        self.df = df.loc[(df.index >= start) & (df.index <= end)].reset_index()
        self.start_ind = self.df[self.df.Date>=self.start].index.min()
           
    
    @staticmethod
    def _strfdate(date):
        return dt.strftime(date, '%Y-%m-%d')
           
    
    def split_by_date(self):
        self.end_ind = self.start_ind + self.duration
        
        dates = []
        
        while self.end_ind <=  len(self.df) - self.prediction_period:
            date_start = self._strfdate(self.df.Date[self.start_ind])
            date_end = self._strfdate(self.df.Date[self.end_ind])
            
            dates.append([date_start, date_end])
            
            self.start_ind += self.window
            self.end_ind = self.start_ind + self.duration
            
        return dates
    
    
    def get_val_map(self, start='2020-06-01', end='2020-12-31'):
        start_ind = self.df[self.df.Date>=start].index.min()
        end_ind = self.df[self.df.Date<=end].index.max()
        
        return {self._strfdate(self.df.Date[n-5]):self._strfdate(self.df.Date[n]) for n in range(start_ind, end_ind+1)}

# %%
split = train_val_split(df)
train_date_list = split.split_by_date()

# %% [markdown]
# ## Get Model

# %%
from google.cloud import bigquery as bq
from tqdm import tqdm
from time import sleep

# %%
client = bq.Client.from_service_account_json("service-account-file.json")
coeff_dict = {}

for n, date in enumerate(tqdm(train_date_list)):
    # delete previous model
    query = "DROP MODEL IF EXISTS ioracle.main.arima_test"
    client.query(query)
#     print("dropped")

    start, end = date[0], date[1]
    #create model
    query1 = f"""
            CREATE OR REPLACE MODEL ioracle.main.arima_test
            OPTIONS
              (model_type = 'ARIMA_PLUS',
               time_series_timestamp_col = 'Date',
               time_series_data_col = 'Adj_Close',
               auto_arima = TRUE,
               data_frequency = 'DAILY',
               decompose_time_series = TRUE,
               holiday_region='US',
               CLEAN_SPIKES_AND_DIPS=FALSE
              ) AS
            SELECT Date, Adj_Close
            FROM `ioracle.main.aapl_data`
            WHERE Date BETWEEN '{start}' AND '{end}'
            ORDER BY Date ASC"""

    client.query(query1)
#     print("model queried")
    
    #cannot scale cos will be new scaler with evey training
    query2 = """
            SELECT
             *
            FROM
             ML.EVALUATE(MODEL ioracle.main.arima_test)
            """
    
    while True:
        try:   
            results = client.query(query2).to_dataframe()
            val_series = results.sort_values('log_likelihood', ascending=False).iloc[0]
   
            coeff_dict[n] = val_series[:4].to_dict()
            break
        except:
            sleep(1)#give time for model to be built
    
    
    #iterate through training periods
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 531/531 [1:24:05<00:00,  9.50s/it]

# %%
coeff_dict
# Out:
# {0: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  1: {'non_seasonal_p': 5,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 0,
#   'has_drift': False},
#  2: {'non_seasonal_p': 5,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 0,
#   'has_drift': True},
#  3: {'non_seasonal_p': 5,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 0,
#   'has_drift': True},
#  4: {'non_seasonal_p': 5,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 0,
#   'has_drift': True},
#  5: {'non_seasonal_p': 5,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 0,
#   'has_drift': True},
#  6: {'non_seasonal_p': 5,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 0,
#   'has_drift': True},
#  7: {'non_seasonal_p': 5,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 0,
#   'has_drift': True},
#  8: {'non_seasonal_p': 5,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 0,
#   'has_drift': True},
#  9: {'non_seasonal_p': 5,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 0,
#   'has_drift': True},
#  10: {'non_seasonal_p': 5,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 0,
#   'has_drift': True},
#  11: {'non_seasonal_p': 5,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 0,
#   'has_drift': True},
#  12: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  13: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  14: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  15: {'non_seasonal_p': 5,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 0,
#   'has_drift': True},
#  16: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  17: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  18: {'non_seasonal_p': 5,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 0,
#   'has_drift': True},
#  19: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': False},
#  20: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  21: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  22: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  23: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  24: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': False},
#  25: {'non_seasonal_p': 0,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 5,
#   'has_drift': False},
#  26: {'non_seasonal_p': 4,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 1,
#   'has_drift': False},
#  27: {'non_seasonal_p': 2,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 3,
#   'has_drift': False},
#  28: {'non_seasonal_p': 2,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 3,
#   'has_drift': False},
#  29: {'non_seasonal_p': 2,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 3,
#   'has_drift': False},
#  30: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  31: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  32: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  33: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  34: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': False},
#  35: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  36: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  37: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  38: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': False},
#  39: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  40: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': False},
#  41: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  42: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  43: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  44: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  45: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  46: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  47: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  48: {'non_seasonal_p': 1,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 4,
#   'has_drift': False},
#  49: {'non_seasonal_p': 1,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 4,
#   'has_drift': False},
#  50: {'non_seasonal_p': 3,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 2,
#   'has_drift': False},
#  51: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  52: {'non_seasonal_p': 3,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 2,
#   'has_drift': False},
#  53: {'non_seasonal_p': 0,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 5,
#   'has_drift': False},
#  54: {'non_seasonal_p': 0,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 5,
#   'has_drift': False},
#  55: {'non_seasonal_p': 3,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 1,
#   'has_drift': False},
#  56: {'non_seasonal_p': 3,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 2,
#   'has_drift': False},
#  57: {'non_seasonal_p': 3,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 1,
#   'has_drift': False},
#  58: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  59: {'non_seasonal_p': 5,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 0,
#   'has_drift': True},
#  60: {'non_seasonal_p': 5,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 0,
#   'has_drift': True},
#  61: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': False},
#  62: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  63: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  64: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  65: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  66: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  67: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  68: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  69: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  70: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  71: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  72: {'non_seasonal_p': 4,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': True},
#  73: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  74: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  75: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  76: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  77: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  78: {'non_seasonal_p': 5,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 0,
#   'has_drift': False},
#  79: {'non_seasonal_p': 1,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 4,
#   'has_drift': False},
#  80: {'non_seasonal_p': 3,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 2,
#   'has_drift': False},
#  81: {'non_seasonal_p': 4,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 1,
#   'has_drift': False},
#  82: {'non_seasonal_p': 3,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 2,
#   'has_drift': False},
#  83: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  84: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  85: {'non_seasonal_p': 4,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': True},
#  86: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  87: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  88: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  89: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  90: {'non_seasonal_p': 5,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 0,
#   'has_drift': False},
#  91: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  92: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  93: {'non_seasonal_p': 4,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': True},
#  94: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  95: {'non_seasonal_p': 4,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': True},
#  96: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': False},
#  97: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  98: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': False},
#  99: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  100: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  101: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  102: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  103: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': False},
#  104: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': False},
#  105: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  106: {'non_seasonal_p': 1,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 3,
#   'has_drift': False},
#  107: {'non_seasonal_p': 2,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 3,
#   'has_drift': False},
#  108: {'non_seasonal_p': 3,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 2,
#   'has_drift': False},
#  109: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  110: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  111: {'non_seasonal_p': 1,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 4,
#   'has_drift': False},
#  112: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  113: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': False},
#  114: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  115: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  116: {'non_seasonal_p': 4,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': True},
#  117: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  118: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  119: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  120: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  121: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  122: {'non_seasonal_p': 5,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 0,
#   'has_drift': True},
#  123: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  124: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  125: {'non_seasonal_p': 5,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 0,
#   'has_drift': True},
#  126: {'non_seasonal_p': 5,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 0,
#   'has_drift': True},
#  127: {'non_seasonal_p': 5,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 0,
#   'has_drift': True},
#  128: {'non_seasonal_p': 5,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 0,
#   'has_drift': True},
#  129: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  130: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  131: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  132: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  133: {'non_seasonal_p': 5,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 0,
#   'has_drift': True},
#  134: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  135: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  136: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  137: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  138: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  139: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  140: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  141: {'non_seasonal_p': 4,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': True},
#  142: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  143: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  144: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  145: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  146: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  147: {'non_seasonal_p': 4,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': True},
#  148: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  149: {'non_seasonal_p': 4,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': True},
#  150: {'non_seasonal_p': 4,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': True},
#  151: {'non_seasonal_p': 4,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': True},
#  152: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  153: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  154: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  155: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  156: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  157: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  158: {'non_seasonal_p': 4,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': True},
#  159: {'non_seasonal_p': 5,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 0,
#   'has_drift': False},
#  160: {'non_seasonal_p': 5,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 0,
#   'has_drift': False},
#  161: {'non_seasonal_p': 3,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 2,
#   'has_drift': False},
#  162: {'non_seasonal_p': 3,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 1,
#   'has_drift': False},
#  163: {'non_seasonal_p': 0,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 5,
#   'has_drift': False},
#  164: {'non_seasonal_p': 0,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 5,
#   'has_drift': False},
#  165: {'non_seasonal_p': 3,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 2,
#   'has_drift': False},
#  166: {'non_seasonal_p': 3,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 2,
#   'has_drift': False},
#  167: {'non_seasonal_p': 3,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 2,
#   'has_drift': False},
#  168: {'non_seasonal_p': 1,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 4,
#   'has_drift': False},
#  169: {'non_seasonal_p': 0,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 5,
#   'has_drift': False},
#  170: {'non_seasonal_p': 3,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 2,
#   'has_drift': False},
#  171: {'non_seasonal_p': 4,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 1,
#   'has_drift': False},
#  172: {'non_seasonal_p': 0,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 5,
#   'has_drift': False},
#  173: {'non_seasonal_p': 2,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 3,
#   'has_drift': False},
#  174: {'non_seasonal_p': 2,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 3,
#   'has_drift': False},
#  175: {'non_seasonal_p': 2,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 3,
#   'has_drift': False},
#  176: {'non_seasonal_p': 1,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 4,
#   'has_drift': False},
#  177: {'non_seasonal_p': 1,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 4,
#   'has_drift': False},
#  178: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  179: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  180: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  181: {'non_seasonal_p': 4,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': False},
#  182: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  183: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  184: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  185: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': False},
#  186: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  187: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  188: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  189: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  190: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  191: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  192: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  193: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  194: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': False},
#  195: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  196: {'non_seasonal_p': 5,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 0,
#   'has_drift': True},
#  197: {'non_seasonal_p': 5,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 0,
#   'has_drift': True},
#  198: {'non_seasonal_p': 5,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 0,
#   'has_drift': True},
#  199: {'non_seasonal_p': 5,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 0,
#   'has_drift': True},
#  200: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  201: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  202: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  203: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  204: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': False},
#  205: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  206: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  207: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  208: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  209: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  210: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  211: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  212: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  213: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  214: {'non_seasonal_p': 4,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': True},
#  215: {'non_seasonal_p': 4,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': True},
#  216: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  217: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  218: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  219: {'non_seasonal_p': 4,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': True},
#  220: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  221: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  222: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  223: {'non_seasonal_p': 4,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': True},
#  224: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  225: {'non_seasonal_p': 4,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': True},
#  226: {'non_seasonal_p': 4,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': True},
#  227: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': False},
#  228: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  229: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  230: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': False},
#  231: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': False},
#  232: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  233: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  234: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  235: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  236: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  237: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  238: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': True},
#  239: {'non_seasonal_p': 4,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': True},
#  240: {'non_seasonal_p': 0,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 5,
#   'has_drift': False},
#  241: {'non_seasonal_p': 5,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 0,
#   'has_drift': False},
#  242: {'non_seasonal_p': 0,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 5,
#   'has_drift': False},
#  243: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': False},
#  244: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  245: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  246: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  247: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  248: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  249: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  250: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  251: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  252: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  253: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  254: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  255: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  256: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  257: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  258: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  259: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  260: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  261: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  262: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  263: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  264: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  265: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  266: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  267: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  268: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  269: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  270: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': True},
#  271: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  272: {'non_seasonal_p': 4,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': True},
#  273: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  274: {'non_seasonal_p': 2,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 3,
#   'has_drift': False},
#  275: {'non_seasonal_p': 0,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 5,
#   'has_drift': False},
#  276: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  277: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  278: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  279: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  280: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  281: {'non_seasonal_p': 4,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': True},
#  282: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  283: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  284: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  285: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  286: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  287: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  288: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  289: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  290: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  291: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  292: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  293: {'non_seasonal_p': 4,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': True},
#  294: {'non_seasonal_p': 4,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': True},
#  295: {'non_seasonal_p': 4,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': True},
#  296: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  297: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  298: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  299: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  300: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  301: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  302: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  303: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  304: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  305: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': False},
#  306: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  307: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': False},
#  308: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  309: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  310: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  311: {'non_seasonal_p': 5,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 0,
#   'has_drift': False},
#  312: {'non_seasonal_p': 2,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 3,
#   'has_drift': False},
#  313: {'non_seasonal_p': 0,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 5,
#   'has_drift': False},
#  314: {'non_seasonal_p': 5,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 0,
#   'has_drift': False},
#  315: {'non_seasonal_p': 5,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 0,
#   'has_drift': False},
#  316: {'non_seasonal_p': 2,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 3,
#   'has_drift': False},
#  317: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  318: {'non_seasonal_p': 0,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 5,
#   'has_drift': False},
#  319: {'non_seasonal_p': 2,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 3,
#   'has_drift': False},
#  320: {'non_seasonal_p': 2,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 3,
#   'has_drift': False},
#  321: {'non_seasonal_p': 5,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 0,
#   'has_drift': True},
#  322: {'non_seasonal_p': 4,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': True},
#  323: {'non_seasonal_p': 4,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': True},
#  324: {'non_seasonal_p': 4,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': True},
#  325: {'non_seasonal_p': 4,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': True},
#  326: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  327: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  328: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  329: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  330: {'non_seasonal_p': 2,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 3,
#   'has_drift': False},
#  331: {'non_seasonal_p': 3,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 2,
#   'has_drift': False},
#  332: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  333: {'non_seasonal_p': 0,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 5,
#   'has_drift': False},
#  334: {'non_seasonal_p': 0,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 5,
#   'has_drift': False},
#  335: {'non_seasonal_p': 0,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 5,
#   'has_drift': False},
#  336: {'non_seasonal_p': 0,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 5,
#   'has_drift': False},
#  337: {'non_seasonal_p': 0,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 5,
#   'has_drift': False},
#  338: {'non_seasonal_p': 0,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 5,
#   'has_drift': False},
#  339: {'non_seasonal_p': 0,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 5,
#   'has_drift': False},
#  340: {'non_seasonal_p': 0,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 5,
#   'has_drift': False},
#  341: {'non_seasonal_p': 4,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': True},
#  342: {'non_seasonal_p': 5,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 0,
#   'has_drift': True},
#  343: {'non_seasonal_p': 4,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': True},
#  344: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  345: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  346: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  347: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  348: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  349: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  350: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  351: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  352: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  353: {'non_seasonal_p': 4,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': True},
#  354: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  355: {'non_seasonal_p': 2,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 3,
#   'has_drift': False},
#  356: {'non_seasonal_p': 5,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 0,
#   'has_drift': True},
#  357: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  358: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  359: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  360: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  361: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  362: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  363: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  364: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  365: {'non_seasonal_p': 4,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': True},
#  366: {'non_seasonal_p': 4,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': True},
#  367: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  368: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  369: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  370: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  371: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  372: {'non_seasonal_p': 0,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 5,
#   'has_drift': False},
#  373: {'non_seasonal_p': 0,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 5,
#   'has_drift': False},
#  374: {'non_seasonal_p': 0,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 5,
#   'has_drift': False},
#  375: {'non_seasonal_p': 0,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 5,
#   'has_drift': False},
#  376: {'non_seasonal_p': 2,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 3,
#   'has_drift': False},
#  377: {'non_seasonal_p': 3,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 2,
#   'has_drift': False},
#  378: {'non_seasonal_p': 2,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 3,
#   'has_drift': False},
#  379: {'non_seasonal_p': 2,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 3,
#   'has_drift': False},
#  380: {'non_seasonal_p': 2,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 3,
#   'has_drift': False},
#  381: {'non_seasonal_p': 2,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 2,
#   'has_drift': False},
#  382: {'non_seasonal_p': 3,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 2,
#   'has_drift': False},
#  383: {'non_seasonal_p': 3,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 2,
#   'has_drift': False},
#  384: {'non_seasonal_p': 0,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 5,
#   'has_drift': False},
#  385: {'non_seasonal_p': 3,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 2,
#   'has_drift': False},
#  386: {'non_seasonal_p': 0,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 5,
#   'has_drift': False},
#  387: {'non_seasonal_p': 2,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 3,
#   'has_drift': False},
#  388: {'non_seasonal_p': 3,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 2,
#   'has_drift': False},
#  389: {'non_seasonal_p': 3,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 2,
#   'has_drift': False},
#  390: {'non_seasonal_p': 3,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 2,
#   'has_drift': False},
#  391: {'non_seasonal_p': 0,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 5,
#   'has_drift': False},
#  392: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  393: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  394: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  395: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  396: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': False},
#  397: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  398: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  399: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  400: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  401: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  402: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  403: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  404: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  405: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  406: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  407: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  408: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 1,
#   'has_drift': True},
#  409: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': False},
#  410: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': False},
#  411: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': False},
#  412: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  413: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  414: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  415: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  416: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  417: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  418: {'non_seasonal_p': 5,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 0,
#   'has_drift': True},
#  419: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  420: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  421: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  422: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  423: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  424: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  425: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': False},
#  426: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  427: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  428: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  429: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  430: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  431: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  432: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  433: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  434: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  435: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  436: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  437: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  438: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  439: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  440: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  441: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  442: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  443: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  444: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  445: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  446: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  447: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  448: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  449: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  450: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  451: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  452: {'non_seasonal_p': 1,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 4,
#   'has_drift': False},
#  453: {'non_seasonal_p': 1,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 4,
#   'has_drift': False},
#  454: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  455: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  456: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  457: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  458: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  459: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  460: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  461: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  462: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  463: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  464: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  465: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  466: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  467: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  468: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  469: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  470: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  471: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  472: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  473: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  474: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  475: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  476: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  477: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  478: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  479: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  480: {'non_seasonal_p': 1,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 4,
#   'has_drift': False},
#  481: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  482: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  483: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  484: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  485: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  486: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  487: {'non_seasonal_p': 5,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 0,
#   'has_drift': True},
#  488: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  489: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  490: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  491: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  492: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  493: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  494: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  495: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  496: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  497: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  498: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  499: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  500: {'non_seasonal_p': 5,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 0,
#   'has_drift': True},
#  501: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  502: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': False},
#  503: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  504: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  505: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  506: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': False},
#  507: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': False},
#  508: {'non_seasonal_p': 3,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 2,
#   'has_drift': False},
#  509: {'non_seasonal_p': 0,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 5,
#   'has_drift': False},
#  510: {'non_seasonal_p': 0,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 5,
#   'has_drift': False},
#  511: {'non_seasonal_p': 1,
#   'non_seasonal_d': 0,
#   'non_seasonal_q': 3,
#   'has_drift': False},
#  512: {'non_seasonal_p': 3,
#   'non_seasonal_d': 2,
#   'non_seasonal_q': 2,
#   'has_drift': False},
#  513: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  514: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  515: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  516: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  517: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  518: {'non_seasonal_p': 3,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 2,
#   'has_drift': True},
#  519: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  520: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  521: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  522: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  523: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  524: {'non_seasonal_p': 2,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 3,
#   'has_drift': True},
#  525: {'non_seasonal_p': 1,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 4,
#   'has_drift': True},
#  526: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  527: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  528: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  529: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True},
#  530: {'non_seasonal_p': 0,
#   'non_seasonal_d': 1,
#   'non_seasonal_q': 5,
#   'has_drift': True}}

# %%
from statistics import mode
def get_mode(dic):
    count_list = []
    for v in dic.values():
        count_list.append(tuple([v[k] for k in v]))
    results = mode(count_list) 
    return results[:3], results[-1]
    

non_seasonal_order, include_drift = get_mode(coeff_dict)  
non_seasonal_order, include_drift
# Out:
# ((0, 1, 5), True)

# %%
#hard code (if model not run)
non_seasonal_order = (0, 1, 5)
include_drift = True

# %%
val_split = train_val_split(df, end='2020-12-31')
val_map = val_split.get_val_map()
val_map
# Out:
# {'2020-05-22': '2020-06-01',
#  '2020-05-26': '2020-06-02',
#  '2020-05-27': '2020-06-03',
#  '2020-05-28': '2020-06-04',
#  '2020-05-29': '2020-06-05',
#  '2020-06-01': '2020-06-08',
#  '2020-06-02': '2020-06-09',
#  '2020-06-03': '2020-06-10',
#  '2020-06-04': '2020-06-11',
#  '2020-06-05': '2020-06-12',
#  '2020-06-08': '2020-06-15',
#  '2020-06-09': '2020-06-16',
#  '2020-06-10': '2020-06-17',
#  '2020-06-11': '2020-06-18',
#  '2020-06-12': '2020-06-19',
#  '2020-06-15': '2020-06-22',
#  '2020-06-16': '2020-06-23',
#  '2020-06-17': '2020-06-24',
#  '2020-06-18': '2020-06-25',
#  '2020-06-19': '2020-06-26',
#  '2020-06-22': '2020-06-29',
#  '2020-06-23': '2020-06-30',
#  '2020-06-24': '2020-07-01',
#  '2020-06-25': '2020-07-02',
#  '2020-06-26': '2020-07-06',
#  '2020-06-29': '2020-07-07',
#  '2020-06-30': '2020-07-08',
#  '2020-07-01': '2020-07-09',
#  '2020-07-02': '2020-07-10',
#  '2020-07-06': '2020-07-13',
#  '2020-07-07': '2020-07-14',
#  '2020-07-08': '2020-07-15',
#  '2020-07-09': '2020-07-16',
#  '2020-07-10': '2020-07-17',
#  '2020-07-13': '2020-07-20',
#  '2020-07-14': '2020-07-21',
#  '2020-07-15': '2020-07-22',
#  '2020-07-16': '2020-07-23',
#  '2020-07-17': '2020-07-24',
#  '2020-07-20': '2020-07-27',
#  '2020-07-21': '2020-07-28',
#  '2020-07-22': '2020-07-29',
#  '2020-07-23': '2020-07-30',
#  '2020-07-24': '2020-07-31',
#  '2020-07-27': '2020-08-03',
#  '2020-07-28': '2020-08-04',
#  '2020-07-29': '2020-08-05',
#  '2020-07-30': '2020-08-06',
#  '2020-07-31': '2020-08-07',
#  '2020-08-03': '2020-08-10',
#  '2020-08-04': '2020-08-11',
#  '2020-08-05': '2020-08-12',
#  '2020-08-06': '2020-08-13',
#  '2020-08-07': '2020-08-14',
#  '2020-08-10': '2020-08-17',
#  '2020-08-11': '2020-08-18',
#  '2020-08-12': '2020-08-19',
#  '2020-08-13': '2020-08-20',
#  '2020-08-14': '2020-08-21',
#  '2020-08-17': '2020-08-24',
#  '2020-08-18': '2020-08-25',
#  '2020-08-19': '2020-08-26',
#  '2020-08-20': '2020-08-27',
#  '2020-08-21': '2020-08-28',
#  '2020-08-24': '2020-08-31',
#  '2020-08-25': '2020-09-01',
#  '2020-08-26': '2020-09-02',
#  '2020-08-27': '2020-09-03',
#  '2020-08-28': '2020-09-04',
#  '2020-08-31': '2020-09-08',
#  '2020-09-01': '2020-09-09',
#  '2020-09-02': '2020-09-10',
#  '2020-09-03': '2020-09-11',
#  '2020-09-04': '2020-09-14',
#  '2020-09-08': '2020-09-15',
#  '2020-09-09': '2020-09-16',
#  '2020-09-10': '2020-09-17',
#  '2020-09-11': '2020-09-18',
#  '2020-09-14': '2020-09-21',
#  '2020-09-15': '2020-09-22',
#  '2020-09-16': '2020-09-23',
#  '2020-09-17': '2020-09-24',
#  '2020-09-18': '2020-09-25',
#  '2020-09-21': '2020-09-28',
#  '2020-09-22': '2020-09-29',
#  '2020-09-23': '2020-09-30',
#  '2020-09-24': '2020-10-01',
#  '2020-09-25': '2020-10-02',
#  '2020-09-28': '2020-10-05',
#  '2020-09-29': '2020-10-06',
#  '2020-09-30': '2020-10-07',
#  '2020-10-01': '2020-10-08',
#  '2020-10-02': '2020-10-09',
#  '2020-10-05': '2020-10-12',
#  '2020-10-06': '2020-10-13',
#  '2020-10-07': '2020-10-14',
#  '2020-10-08': '2020-10-15',
#  '2020-10-09': '2020-10-16',
#  '2020-10-12': '2020-10-19',
#  '2020-10-13': '2020-10-20',
#  '2020-10-14': '2020-10-21',
#  '2020-10-15': '2020-10-22',
#  '2020-10-16': '2020-10-23',
#  '2020-10-19': '2020-10-26',
#  '2020-10-20': '2020-10-27',
#  '2020-10-21': '2020-10-28',
#  '2020-10-22': '2020-10-29',
#  '2020-10-23': '2020-10-30',
#  '2020-10-26': '2020-11-02',
#  '2020-10-27': '2020-11-03',
#  '2020-10-28': '2020-11-04',
#  '2020-10-29': '2020-11-05',
#  '2020-10-30': '2020-11-06',
#  '2020-11-02': '2020-11-09',
#  '2020-11-03': '2020-11-10',
#  '2020-11-04': '2020-11-11',
#  '2020-11-05': '2020-11-12',
#  '2020-11-06': '2020-11-13',
#  '2020-11-09': '2020-11-16',
#  '2020-11-10': '2020-11-17',
#  '2020-11-11': '2020-11-18',
#  '2020-11-12': '2020-11-19',
#  '2020-11-13': '2020-11-20',
#  '2020-11-16': '2020-11-23',
#  '2020-11-17': '2020-11-24',
#  '2020-11-18': '2020-11-25',
#  '2020-11-19': '2020-11-27',
#  '2020-11-20': '2020-11-30',
#  '2020-11-23': '2020-12-01',
#  '2020-11-24': '2020-12-02',
#  '2020-11-25': '2020-12-03',
#  '2020-11-27': '2020-12-04',
#  '2020-11-30': '2020-12-07',
#  '2020-12-01': '2020-12-08',
#  '2020-12-02': '2020-12-09',
#  '2020-12-03': '2020-12-10',
#  '2020-12-04': '2020-12-11',
#  '2020-12-07': '2020-12-14',
#  '2020-12-08': '2020-12-15',
#  '2020-12-09': '2020-12-16',
#  '2020-12-10': '2020-12-17',
#  '2020-12-11': '2020-12-18',
#  '2020-12-14': '2020-12-21',
#  '2020-12-15': '2020-12-22',
#  '2020-12-16': '2020-12-23',
#  '2020-12-17': '2020-12-24',
#  '2020-12-18': '2020-12-28',
#  '2020-12-21': '2020-12-29',
#  '2020-12-22': '2020-12-30',
#  '2020-12-23': '2020-12-31'}

# %%
train_start = '2018-01-01'
val_start = '2020-06-01'
val_end = '2020-12-31'

# %%
from time import sleep

pred_list=[]

for k, v in tqdm(val_map.items()):

    query3 = "DROP MODEL IF EXISTS ioracle.main.arima_model"
    client.query(query3)
    
    query4 = f"""
    CREATE OR REPLACE MODEL ioracle.main.arima_model
    OPTIONS
      (model_type = 'ARIMA_PLUS',
       time_series_timestamp_col = 'Date',
       time_series_data_col = 'Adj_Close',
       auto_arima = FALSE,
       data_frequency = 'DAILY',
       decompose_time_series = TRUE,
       holiday_region='US',
       CLEAN_SPIKES_AND_DIPS=FALSE,
       NON_SEASONAL_ORDER={non_seasonal_order},
       INCLUDE_DRIFT={include_drift}
      ) AS
    SELECT Date, Adj_Close
    FROM `ioracle.main.aapl_data`
    WHERE Date BETWEEN '{train_start}' AND '{k}'
    ORDER BY Date ASC"""

    client.query(query4)
    
    query5 = """
    SELECT
     *
    FROM
     ML.FORECAST(MODEL ioracle.main.arima_model,
     STRUCT(20 AS horizon)
     )
    """
    
    while True:
        try:
            forecast = client.query(query5).to_dataframe()
            forecast['Date'] = forecast.forecast_timestamp.apply(lambda x: dt.strftime(x, '%Y-%m-%d'))
            pred_list.append(forecast.set_index('Date').loc[v,'forecast_value'])
            break
        except:
            sleep(1) # give time for model to be built
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 150/150 [22:15<00:00,  8.91s/it]

# %%
def get_y(df, start, end):
    return df.loc[(df.index>=start) & (df.index<=end)]['Adj Close']

y = get_y(df, val_start, val_end)

# %%
# save prediction dataframe to csv
pd.DataFrame(pred_list, index=y.index, columns=['y_pred']).to_csv('aapl_arima_pred.csv')

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(y, pred_list)
# Out:
# 4.561292747905219
